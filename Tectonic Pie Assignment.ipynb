# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#          country  gold_medal
# 0  United States          46
# 1  Great Britain          27
# 2          China          26
# 3         Russia          19
# 4        Germany          17

# %%
a = df['gold_medal'].values
b = df['country'].values

# %%
a
# Out:
# array([46, 27, 26, 19, 17], dtype=int64)

# %%
b
# Out:
# array(['United States', 'Great Britain', 'China', 'Russia', 'Germany'],
#       dtype=object)

# %%
plt.axis('equal')
plt.pie(a,labels=b,colors=['red','yellow'],autopct='%.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x18409a22d08>,
# ...
#  [Text(0.5276844259140197, 0.9651679370181085, 'United States'),
#   Text(-1.0246277154553132, 0.40017251869765635, 'Great Britain'),
#   Text(-0.7168229424450668, -0.8343649496379847, 'China'),
#   Text(0.3641697549943344, -1.037969358674603, 'Russia'),
#   Text(1.015038685557071, -0.4239062005002681, 'Germany')],
#  [Text(0.28782786868037435, 0.5264552383735137, '34.1'),
#   Text(-0.558887844793807, 0.21827591928963072, '20.0'),
#   Text(-0.3909943322427637, -0.45510815434799157, '19.3'),
#   Text(0.19863804817872782, -0.5661651047316016, '14.1'),
#   Text(0.5536574648493114, -0.23122156390923712, '12.6')])

# %%
plt.axis('equal')
plt.pie(a,labels=b,colors=['red','yellow','green','blue','cyan'],autopct='%.2f',explode=arr,shadow=True)
arr=[0,0,1,0,0]
plt.legend(b)

# %%
plt.axis('equal')
plt.pie(a,labels=b,colors=['red','yellow'],autopct='%.1f',explode=arr)
arr=[0,0,0,1,0]

# %%
plt.axis('equal')
plt.pie(a,labels=b,colors=['red','yellow','green','blue','cyan'],autopct='%.2f',explode=arr,shadow=True)
arr=[0,0,1,0,0]
